# %% [markdown]
# #Libraries

# %%
# Importing libraries for data manipulation
import numpy as np

import pandas as pd

# Importing libraries for data visualization
import seaborn as sns

import matplotlib.pyplot as plt

# Importing libraries for building linear regression model
import statsmodels.api as sm

from statsmodels.stats.outliers_influence import variance_inflation_factor

# Importing libraries for scaling the data
from sklearn.preprocessing import MinMaxScaler

# To ignore warnings
import warnings
warnings.filterwarnings("ignore")

from scipy.stats import skew

import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split
from scipy.stats import skew

import missingno as msno # to get visualization on missing values

# To build models for prediction
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor

# For tuning the model
from sklearn.model_selection import GridSearchCV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/CrAutos Project/CRautosData.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11056 entries, 0 to 11055
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CRA_URL             11056 non-null  object
#  1   Modelo              11056 non-null  object
#  2   Precio1             11056 non-null  object
#  3   Precio2             11056 non-null  object
#  4   Equipamiento        10635 non-null  object
#  5   Cilindrada          11056 non-null  object
#  6   Estilo              11056 non-null  object
#  7   # de pasajeros      11056 non-null  object
#  8   Combustible         11056 non-null  object
#  9   Transmisión         11056 non-null  object
#  10  Estado              11056 non-null  object
#  11  Kilometraje         11056 non-null  object
#  12  Placa               11056 non-null  object
#  13  Color exterior      11056 non-null  object
#  14  Color interior      11025 non-null  object
#  15  # de puertas        11056 non-null  int64
#  16  Ya pagó impuestos   11056 non-null  object
#  17  Precio negociable   11056 non-null  object
#  18  Se recibe vehículo  11056 non-null  object
#  19  Provincia           11056 non-null  object
#  20  Fecha de ingreso    11056 non-null  object
# dtypes: int64(1), object(20)
# memory usage: 1.8+ MB

# %%
df.head(10)
# Out:
#                                              CRA_URL                   Modelo  \
# 0  https://crautos.com/autosusados/cardetail.cfm?...            Geely CK 2007
# 1  https://crautos.com/autosusados/cardetail.cfm?...         Toyota 1000 1979
# 2  https://crautos.com/autosusados/cardetail.cfm?...  Chevrolet CAVALIER 1999
# 3  https://crautos.com/autosusados/cardetail.cfm?...     Chevrolet SPARK 2009
# 4  https://crautos.com/autosusados/cardetail.cfm?...   Mitsubishi MIRAGE 1996
# 5  https://crautos.com/autosusados/cardetail.cfm?...       Subaru LOYALE 1993
# 6  https://crautos.com/autosusados/cardetail.cfm?...         Audi 100 CD 1987
# 7  https://crautos.com/autosusados/cardetail.cfm?...      Changan STAR 2 2014
# 8  https://crautos.com/autosusados/cardetail.cfm?...      Hyundai ACCENT 1995
# 9  https://crautos.com/autosusados/cardetail.cfm?...     Toyota COROLLA  1989
#
#      Precio1     Precio2                                       Equipamiento  \
# 0  ¢ 300,000    ($ 594)*               Dirección Hidráulica/Electroasistida
# 1  ¢ 350,000    ($ 693)*                                                NaN
# 2  ¢ 500,000    ($ 990)*  Dirección Hidráulica/Electroasistida     Cierr...
# 3  ¢ 600,000  ($ 1,188)*                                Asientos eléctricos
# 4  ¢ 600,000  ($ 1,188)*  Dirección Hidráulica/Electroasistida     Bolsa...
# 5  ¢ 600,000  ($ 1,188)*  Dirección Hidráulica/Electroasistida     Vidri...
# 6  ¢ 650,000  ($ 1,287)*  Dirección Hidráulica/Electroasistida     Cierr...
# 7  ¢ 650,000  ($ 1,287)*                                                NaN
# 8  ¢ 675,000  ($ 1,337)*                                 Vidrios eléctricos
# 9  ¢ 675,000  ($ 1,337)*                                                NaN
#
#   Cilindrada       Estilo # de pasajeros Combustible      Transmisión  ...  \
# 0    1300 cc        Sedán              5    Gasolina           Manual  ...
# 1    1000 cc  Pick Up 2WD              2    Gasolina           Manual  ...
# 2    2200 cc        Sedán              5    Gasolina           Manual  ...
# 3     800 cc        Sedán              5    Gasolina           Manual  ...
# 4    1500 cc        Sedán              5    Gasolina  Automática/Dual  ...
# 5    1800 cc        Pánel              4    Gasolina           Manual  ...
# 6    2226 cc        Sedán              5    Gasolina           Manual  ...
# 7    1300 cc        Pánel              2    Gasolina           Manual  ...
# 8    1500 cc        Sedán              5    Gasolina  Automática/Dual  ...
# 9    1300 cc        Sedán              5    Gasolina           Manual  ...
#
#    Kilometraje         Placa Color exterior Color interior # de puertas  \
# 0  400,000 kms  Termina en 5           ROJO           GRIS            5
# 1  150,000 kms  Termina en 3         BLANCO           GRIS            2
# 2           ND  Termina en 9          VERDE           GRIS            4
# 3  320,000 kms  Termina en 6          NEGRO           GRIS            5
# 4  199,990 kms  Termina en 8           GRIS           GRIS            5
# 5           ND  Termina en 3           GRIS           GRIS            5
# 6  154,000 kms  Termina en 5           GRIS           GRIS            4
# 7   50,000 kms  Termina en 4         BLANCO          NEGRO            4
# 8   77,000 kms  Termina en 8           AZUL          NEGRO            2
# 9           ND  Termina en 3       PLATEADO           GRIS            4
#
#    Ya pagó impuestos Precio negociable Se recibe vehículo   Provincia  \
# 0                 NO                SI                 NO    San José
# 1                 SI                NO                 NO    San José
# 2                 SI                NO                 NO    San José
# 3                 SI                SI                 NO  Guanacaste
# 4                 SI                SI                 NO  Puntarenas
# 5                 SI                NO                 NO    San José
# 6                 SI                SI                 NO     Heredia
# 7                 SI                SI                 NO    San José
# 8                 SI                SI                 NO    San José
# 9                 SI                NO                 NO    San José
#
#        Fecha de ingreso
# 0  19 de Junio del 2025
# 1  07 de Julio del 2025
# 2  23 de Julio del 2025
# 3  01 de Julio del 2025
# 4  08 de Julio del 2025
# 5  28 de Julio del 2025
# 6  02 de Julio del 2025
# 7  29 de Julio del 2025
# 8  23 de Junio del 2025
# 9  24 de Junio del 2025
#
# [10 rows x 21 columns]

# %% [markdown]
# #Data Cleaning

# %%
# Sample exchange rate
usd_to_crc = 505
crc_to_usd = 1 / usd_to_crc

# Clean Precio1 (should be in colones)
def clean_precio1(value):
    if pd.isna(value):
        return np.nan
    value = str(value).replace(',', '').replace('*', '').replace('(', '').replace(')', '').strip()
    if '$' in value:
        try:
            amount = float(value.replace('$', '').strip())
            return round(amount * usd_to_crc)
        except:
            return np.nan
    elif '¢' in value:
        try:
            return int(value.replace('¢', '').strip())
        except:
            return np.nan
    else:
        return np.nan

# Clean Precio2 (should be in dollars)
def clean_precio2(value):
    if pd.isna(value):
        return np.nan
    value = str(value).replace(',', '').replace('*', '').replace('(', '').replace(')', '').strip()
    if '¢' in value:
        try:
            amount = int(value.replace('¢', '').strip())
            return round(amount * crc_to_usd, 2)
        except:
            return np.nan
    elif '$' in value:
        try:
            return float(value.replace('$', '').strip())
        except:
            return np.nan
    else:
        return np.nan

# Apply to the DataFrame
df['PrecioCRC'] = df['Precio1'].apply(clean_precio1)
df['PrecioUSD'] = df['Precio2'].apply(clean_precio2)

# %%
# 1. Split 'Modelo' into 'Marca' and 'Modelo'
df[['Marca', 'Modelo']] = df['Modelo'].str.extract(r'^(\w+)\s+(.*)')

# 2. Clean 'Cilindrada': remove non-numeric characters, convert to int
df['Cilindrada'] = df['Cilindrada'].str.extract(r'(\d+)').astype(float).astype('Int64')

# %%
# Normalize text columns: Marca and Modelo
df['Marca'] = df['Marca'].str.lower().str.strip()
df['Modelo'] = df['Modelo'].str.lower().str.strip()

# %%
# Step 1: Remove commas
df['Kilometraje_clean'] = df['Kilometraje'].str.replace(',', '', regex=False).str.lower()

# Step 2: Extract numeric values
df['Kilometraje_num'] = df['Kilometraje_clean'].str.extract(r'(\d+)').astype(float)

# Step 3: Determine if value is in miles
is_miles = df['Kilometraje_clean'].str.contains('millas', na=False)

# Step 4: Convert miles to km where applicable
df['Kilometraje_num'] = np.where(is_miles, df['Kilometraje_num'] * 1.60934, df['Kilometraje_num'])

# Step 5: Round and convert to nullable Int64
df['Kilometraje'] = df['Kilometraje_num'].round().astype('Int64')

# Step 6: Drop intermediate columns
df.drop(columns=['Kilometraje_clean', 'Kilometraje_num'], inplace=True)

# %%
df['Placa'] = df['Placa'].str.extract(r'(\d)$').astype('Int64')

# %%
# Drop original price columns
df.drop(columns=['Precio1', 'Precio2'], inplace=True)

# %%
df['Año'] = df['Modelo'].str.extract(r'(\d{4})$').astype('Int64')  # Extract year if it looks like 4 digits
df['Modelo'] = df['Modelo'].str.replace(r'\s*\d{4}$', '', regex=True)

# %%
from datetime import datetime

current_year = datetime.now().year
df['Edad'] = current_year - df['Año']

# %%
df.head(10)
# Out:
#                                              CRA_URL    Modelo  \
# 0  https://crautos.com/autosusados/cardetail.cfm?...        ck
# 1  https://crautos.com/autosusados/cardetail.cfm?...      1000
# 2  https://crautos.com/autosusados/cardetail.cfm?...  cavalier
# 3  https://crautos.com/autosusados/cardetail.cfm?...     spark
# 4  https://crautos.com/autosusados/cardetail.cfm?...    mirage
# 5  https://crautos.com/autosusados/cardetail.cfm?...    loyale
# 6  https://crautos.com/autosusados/cardetail.cfm?...    100 cd
# 7  https://crautos.com/autosusados/cardetail.cfm?...    star 2
# 8  https://crautos.com/autosusados/cardetail.cfm?...    accent
# 9  https://crautos.com/autosusados/cardetail.cfm?...   corolla
#
#                                         Equipamiento  Cilindrada       Estilo  \
# 0               Dirección Hidráulica/Electroasistida        1300        Sedán
# 1                                                NaN        1000  Pick Up 2WD
# 2  Dirección Hidráulica/Electroasistida     Cierr...        2200        Sedán
# 3                                Asientos eléctricos         800        Sedán
# 4  Dirección Hidráulica/Electroasistida     Bolsa...        1500        Sedán
# 5  Dirección Hidráulica/Electroasistida     Vidri...        1800        Pánel
# 6  Dirección Hidráulica/Electroasistida     Cierr...        2226        Sedán
# 7                                                NaN        1300        Pánel
# 8                                 Vidrios eléctricos        1500        Sedán
# 9                                                NaN        1300        Sedán
#
#   # de pasajeros Combustible      Transmisión   Estado  Kilometraje  ...  \
# 0              5    Gasolina           Manual  Regular       400000  ...
# 1              2    Gasolina           Manual  Regular       150000  ...
# 2              5    Gasolina           Manual  Regular         <NA>  ...
# 3              5    Gasolina           Manual  Regular       320000  ...
# 4              5    Gasolina  Automática/Dual  Regular       199990  ...
# 5              4    Gasolina           Manual    Bueno         <NA>  ...
# 6              5    Gasolina           Manual    Bueno       154000  ...
# 7              2    Gasolina           Manual  Regular        50000  ...
# 8              5    Gasolina  Automática/Dual    Bueno        77000  ...
# 9              5    Gasolina           Manual  Regular         <NA>  ...
#
#    Ya pagó impuestos Precio negociable Se recibe vehículo   Provincia  \
# 0                 NO                SI                 NO    San José
# 1                 SI                NO                 NO    San José
# 2                 SI                NO                 NO    San José
# 3                 SI                SI                 NO  Guanacaste
# 4                 SI                SI                 NO  Puntarenas
# 5                 SI                NO                 NO    San José
# 6                 SI                SI                 NO     Heredia
# 7                 SI                SI                 NO    San José
# 8                 SI                SI                 NO    San José
# 9                 SI                NO                 NO    San José
#
#        Fecha de ingreso PrecioCRC PrecioUSD       Marca   Año  Edad
# 0  19 de Junio del 2025    300000     594.0       geely  2007    18
# 1  07 de Julio del 2025    350000     693.0      toyota  1979    46
# 2  23 de Julio del 2025    500000     990.0   chevrolet  1999    26
# 3  01 de Julio del 2025    600000    1188.0   chevrolet  2009    16
# 4  08 de Julio del 2025    600000    1188.0  mitsubishi  1996    29
# 5  28 de Julio del 2025    600000    1188.0      subaru  1993    32
# 6  02 de Julio del 2025    650000    1287.0        audi  1987    38
# 7  29 de Julio del 2025    650000    1287.0     changan  2014    11
# 8  23 de Junio del 2025    675000    1337.0     hyundai  1995    30
# 9  24 de Junio del 2025    675000    1337.0      toyota  1989    36
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Remove duplicates

# %%
duplicates = df[df.duplicated(subset='CRA_URL', keep=False)]

# %%
duplicates
# Out:
#                                                  CRA_URL  \
# 1029   https://crautos.com/autosusados/cardetail.cfm?...
# 1043   https://crautos.com/autosusados/cardetail.cfm?...
# 1102   https://crautos.com/autosusados/cardetail.cfm?...
# 1105   https://crautos.com/autosusados/cardetail.cfm?...
# 1117   https://crautos.com/autosusados/cardetail.cfm?...
# ...                                                  ...
# 10780  https://crautos.com/autosusados/cardetail.cfm?...
# 10861  https://crautos.com/autosusados/cardetail.cfm?...
# 10871  https://crautos.com/autosusados/cardetail.cfm?...
# 10883  https://crautos.com/autosusados/cardetail.cfm?...
# 10890  https://crautos.com/autosusados/cardetail.cfm?...
#
#                         Modelo  \
# 1029                   compass
# 1043                   compass
# 1102                     tiida
# 1105                     tiida
# 1117                     civic
# ...                        ...
# 10780  x4 xdrive 20d m package
# 10861       mustang gt premium
# 10871       mustang gt premium
# 10883                       x7
# 10890                       x7
#
#                                             Equipamiento  Cilindrada  \
# 1029   Cierre central     Vidrios eléctricos     Bols...        2400
# 1043   Cierre central     Vidrios eléctricos     Bols...        2400
# 1102   Dirección Hidráulica/Electroasistida     Cierr...        1600
# 1105   Dirección Hidráulica/Electroasistida     Cierr...        1600
# 1117   Dirección Hidráulica/Electroasistida     Cierr...        1800
# ...                                                  ...         ...
# 10780  Dirección Hidráulica/Electroasistida     Cierr...        2000
# 10861  Dirección Hidráulica/Electroasistida     Cierr...        5000
# 10871  Dirección Hidráulica/Electroasistida     Cierr...        5000
# 10883  Dirección Hidráulica/Electroasistida     Cierr...        3000
# 10890  Dirección Hidráulica/Electroasistida     Cierr...        3000
#
#             Estilo # de pasajeros Combustible      Transmisión     Estado  \
# 1029   SUV 4WD/AWD              5    Gasolina  Automática/Dual      Bueno
# 1043   SUV 4WD/AWD              5    Gasolina  Automática/Dual      Bueno
# 1102     Hatchback              5    Gasolina  Automática/Dual  Excelente
# 1105     Hatchback              5    Gasolina  Automática/Dual  Excelente
# 1117         Sedán              5    Gasolina           Manual      Bueno
# ...            ...            ...         ...              ...        ...
# 10780  SUV 4WD/AWD              5      Diesel  Automática/Dual  Excelente
# 10861        Sedán              4    Gasolina  Automática/Dual  Excelente
# 10871        Sedán              4    Gasolina  Automática/Dual  Excelente
# 10883  SUV 4WD/AWD              7      Diesel  Automática/Dual  Excelente
# 10890  SUV 4WD/AWD              7      Diesel  Automática/Dual  Excelente
#
#        Kilometraje  ...  Ya pagó impuestos Precio negociable  \
# 1029         89072  ...                 SI                SI
# 1043         89072  ...                 SI                SI
# 1102        251000  ...                 SI                SI
# 1105        251000  ...                 SI                SI
# 1117        286463  ...                 SI                SI
# ...            ...  ...                ...               ...
# 10780        54000  ...                 SI                SI
# 10861        14800  ...                 SI                SI
# 10871        14800  ...                 SI                SI
# 10883       101000  ...                 SI                SI
# 10890       101000  ...                 SI                SI
#
#       Se recibe vehículo  Provincia       Fecha de ingreso PrecioCRC  \
# 1029                  NO    Heredia   13 de Junio del 2025   3800000
# 1043                  NO    Heredia   13 de Junio del 2025   3800000
# 1102                  NO    Cartago   28 de Julio del 2025   3850000
# 1105                  NO    Cartago   28 de Julio del 2025   3850000
# 1117                  NO   San José   12 de Junio del 2025   3900000
# ...                  ...        ...                    ...       ...
# 10780                 NO    Heredia  03 de Agosto del 2025  35000000
# 10861                 SI    Heredia   28 de Julio del 2025  40500000
# 10871                 SI    Heredia   28 de Julio del 2025  40500000
# 10883                 NO   Alajuela   10 de Julio del 2025  42000000
# 10890                 NO   Alajuela   10 de Julio del 2025  42000000
#
#       PrecioUSD   Marca   Año  Edad
# 1029     7525.0    jeep  2008    17
# 1043     7525.0    jeep  2008    17
# 1102     7624.0  nissan  2007    18
# 1105     7624.0  nissan  2007    18
# 1117     7723.0   honda  2007    18
# ...         ...     ...   ...   ...
# 10780   69583.0     bmw  2022     3
# 10861   80517.0    ford  2024     1
# 10871   80517.0    ford  2024     1
# 10883   83499.0     bmw  2020     5
# 10890   83499.0     bmw  2020     5
#
# [703 rows x 24 columns]

# %%
#Remove all duplicates
df = df.drop_duplicates(subset='CRA_URL', keep='first')

# %% [markdown]
# ##Missing Values

# %%
df.isnull().sum()
# Out:
# CRA_URL                  0
# Modelo                  92
# Equipamiento           414
# Cilindrada               0
# Estilo                   0
# # de pasajeros           0
# Combustible              0
# Transmisión              0
# Estado                   0
# Kilometraje            267
# Placa                 1235
# Color exterior           0
# Color interior          31
# # de puertas             0
# Ya pagó impuestos        0
# Precio negociable        0
# Se recibe vehículo       0
# Provincia                0
# Fecha de ingreso         0
# PrecioCRC                0
# PrecioUSD               18
# Marca                   92
# Año                     92
# Edad                    92
# dtype: int64

# %%
df[df['PrecioUSD'].isna()]
# Out:
#                                                  CRA_URL           Modelo  \
# 435    https://crautos.com/autosusados/cardetail.cfm?...               f0
# 610    https://crautos.com/autosusados/cardetail.cfm?...               c3
# 1099   https://crautos.com/autosusados/cardetail.cfm?...          picanto
# 1406   https://crautos.com/autosusados/cardetail.cfm?...              i10
# 1421   https://crautos.com/autosusados/cardetail.cfm?...              c30
# 4074   https://crautos.com/autosusados/cardetail.cfm?...            hilux
# 4420   https://crautos.com/autosusados/cardetail.cfm?...       500 lounge
# 4696   https://crautos.com/autosusados/cardetail.cfm?...          sorento
# 5180   https://crautos.com/autosusados/cardetail.cfm?...           captur
# 5601   https://crautos.com/autosusados/cardetail.cfm?...     grand vitara
# 6466   https://crautos.com/autosusados/cardetail.cfm?...     countryman s
# 6882   https://crautos.com/autosusados/cardetail.cfm?...              cx3
# 7867   https://crautos.com/autosusados/cardetail.cfm?...             dmax
# 8176   https://crautos.com/autosusados/cardetail.cfm?...             l200
# 8247   https://crautos.com/autosusados/cardetail.cfm?...          qashqai
# 9381   https://crautos.com/autosusados/cardetail.cfm?...    eclipse cross
# 9664   https://crautos.com/autosusados/cardetail.cfm?...          crv exr
# 10819  https://crautos.com/autosusados/cardetail.cfm?...  rover discovery
#
#                                             Equipamiento  Cilindrada  \
# 435    Dirección Hidráulica/Electroasistida     Cierr...        1000
# 610    Dirección Hidráulica/Electroasistida     Cierr...        1400
# 1099   Cierre central     Alarma     Espejos eléctric...        1080
# 1406   Dirección Hidráulica/Electroasistida     Cierr...        1200
# 1421   Dirección Hidráulica/Electroasistida     Cierr...        2000
# 4074   Dirección Hidráulica/Electroasistida     Cierr...        2800
# 4420   Dirección Hidráulica/Electroasistida     Cierr...        1400
# 4696   Dirección Hidráulica/Electroasistida     Cierr...        2400
# 5180   Dirección Hidráulica/Electroasistida     Cierr...        2000
# 5601   Dirección Hidráulica/Electroasistida     Cierr...        2400
# 6466   Dirección Hidráulica/Electroasistida     Cierr...        2000
# 6882   Dirección Hidráulica/Electroasistida     Cierr...        2000
# 7867   Dirección Hidráulica/Electroasistida     Cierr...        2500
# 8176   Dirección Hidráulica/Electroasistida     Cierr...        2500
# 8247   Dirección Hidráulica/Electroasistida     Cierr...        2000
# 9381   Dirección Hidráulica/Electroasistida     Cierr...        2000
# 9664   Dirección Hidráulica/Electroasistida     Cierr...        1500
# 10819  Dirección Hidráulica/Electroasistida     Cierr...        3000
#
#             Estilo # de pasajeros Combustible      Transmisión     Estado  \
# 435      Hatchback              5    Gasolina           Manual  Excelente
# 610          Sedán              5    Gasolina           Manual  Excelente
# 1099     Hatchback              5    Gasolina           Manual  Excelente
# 1406     Hatchback              5    Gasolina           Manual  Excelente
# 1421     Hatchback              4    Gasolina           Manual  Excelente
# 4074   Pick Up 4WD              3      Diesel           Manual  Excelente
# 4420     Hatchback              4    Gasolina  Automática/Dual  Excelente
# 4696       SUV 2WD              5    Gasolina  Automática/Dual  Excelente
# 5180       SUV 2WD              5    Gasolina  Automática/Dual  Excelente
# 5601   SUV 4WD/AWD              5    Gasolina  Automática/Dual  Excelente
# 6466   SUV 4WD/AWD              5    Gasolina  Automática/Dual  Excelente
# 6882       SUV 2WD              5    Gasolina  Automática/Dual  Excelente
# 7867   Pick Up 2WD              5      Diesel           Manual  Excelente
# 8176   Pick Up 4WD              5      Diesel           Manual  Excelente
# 8247       SUV 2WD              5    Gasolina  Automática/Dual  Excelente
# 9381       SUV 2WD              5    Gasolina  Automática/Dual  Excelente
# 9664       SUV 2WD              5    Gasolina  Automática/Dual  Excelente
# 10819  SUV 4WD/AWD              7      Diesel  Automática/Dual  Excelente
#
#        Kilometraje  ...  Ya pagó impuestos Precio negociable  \
# 435         109000  ...                 SI                NO
# 610         128390  ...                 SI                SI
# 1099        147000  ...                 SI                SI
# 1406        120000  ...                 SI                SI
# 1421        200000  ...                 SI                SI
# 4074        260000  ...                 SI                SI
# 4420         81000  ...                 SI                SI
# 4696         90000  ...                 SI                SI
# 5180         40000  ...                 SI                SI
# 5601        155000  ...                 SI                SI
# 6466         70800  ...                 SI                SI
# 6882        120000  ...                 SI                SI
# 7867         95000  ...                 SI                NO
# 8176        280000  ...                 SI                SI
# 8247         48000  ...                 SI                SI
# 9381         35000  ...                 SI                SI
# 9664         47000  ...                 SI                SI
# 10819        40000  ...                 SI                SI
#
#       Se recibe vehículo  Provincia       Fecha de ingreso PrecioCRC  \
# 435                   NO   San José   18 de Junio del 2025   2800000
# 610                   NO    Cartago   24 de Julio del 2025   3100000
# 1099                  NO   San José   17 de Julio del 2025   3850000
# 1406                  NO    Heredia   02 de Julio del 2025   4200000
# 1421                  NO   San José   15 de Julio del 2025   4200000
# 4074                  NO    Heredia   29 de Julio del 2025   6500000
# 4420                  SI   San José   13 de Julio del 2025   6950000
# 4696                  SI   San José   13 de Julio del 2025   7250000
# 5180                  NO   San José   18 de Julio del 2025   7800000
# 5601                  NO   Alajuela   17 de Julio del 2025   8400000
# 6466                  NO    Heredia   14 de Julio del 2025   9500000
# 6882                  NO    Heredia   28 de Julio del 2025  10000000
# 7867                  NO   San José   10 de Julio del 2025  11900000
# 8176                  NO   Alajuela  01 de Agosto del 2025  12500000
# 8247                  NO   San José   17 de Julio del 2025  12590000
# 9381                  SI   San José   07 de Junio del 2025  16000000
# 9664                  NO   San José    25 de Mayo del 2025  19000000
# 10819                 NO   Alajuela   26 de Junio del 2025  37500000
#
#       PrecioUSD       Marca   Año  Edad
# 435         NaN         byd  2016     9
# 610         NaN     citroen  2013    12
# 1099        NaN         kia  2009    16
# 1406        NaN     hyundai  2009    16
# 1421        NaN       volvo  2008    17
# 4074        NaN      toyota  1990    35
# 4420        NaN        fiat  2016     9
# 4696        NaN         kia  2014    11
# 5180        NaN     renault  2020     5
# 5601        NaN      suzuki  2017     8
# 6466        NaN        mini  2017     8
# 6882        NaN       mazda  2018     7
# 7867        NaN       isuzu  2017     8
# 8176        NaN  mitsubishi  2013    12
# 8247        NaN      nissan  2021     4
# 9381        NaN  mitsubishi  2023     2
# 9664        NaN       honda  2021     4
# 10819       NaN        land  2020     5
#
# [18 rows x 24 columns]

# %% [markdown]
# Filling the PrecioUSD with the conversion of the value of PrecioCRC

# %%
crc_to_usd_rate = 0.00198  # Exchange rate on August 4, 2025

mask = df['PrecioUSD'].isna() & df['PrecioCRC'].notna()

df.loc[mask, 'PrecioUSD'] = (df.loc[mask, 'PrecioCRC'] * crc_to_usd_rate).round(2)

# %% [markdown]
# The equipamento column has multiple words separated by spaces, we will turn all of them into Dummy Variables

# %%
# 1. Your list of equipment features (normalized for matching)
equip_features = [
    'dirección hidráulica/electroasistida', 'cierre central', 'asientos eléctricos',
    'vidrios tintados', 'vidrios eléctricos', 'bolsa de aire', 'alarma',
    'espejos eléctricos', 'frenos abs', 'aire acondicionado', 'desempañador trasero',
    'sunroof/techo panorámico', 'aros de lujo', 'turbo', 'tapicería de cuero',
    'halógenos', 'cámara 360', 'android auto', 'control crucero', 'radio con usb/aux',
    'revisión técnica al día', 'control electrónico de estabilidad', 'control de descenso',
    'caja de cambios dual', 'cámara de retroceso', 'sensores de retroceso', 'sensores frontales',
    'control de radio en el volante', 'volante multifuncional', 'aire acondicionado climatizado',
    'asiento con memoria', 'retrovisores auto-retractibles', 'luces de xenón/bixenón',
    'sensor de lluvia', 'llave inteligente/botón de arranque', 'apple carplay',
    'computadora de viaje', 'volante ajustable', 'bluetooth'
]

# 2. Clean and normalize the Equipamiento column
df['Equipamiento_clean'] = df['Equipamiento'].str.lower().str.replace(r'\s+', ' ', regex=True).str.strip()

# 3. Create dummy variables
for feature in equip_features:
    # Optional: normalize spacing and remove accents if needed
    df[feature] = df['Equipamiento_clean'].apply(
        lambda x: 1 if isinstance(x, str) and feature in x else 0
    )

# %% [markdown]
# Looking at the rows with null values on the column 'Marca'

# %%
df[df['Marca'].isna()]
# Out:
#                                                  CRA_URL Modelo  \
# 19     https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 39     https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 1119   https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 1303   https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 2267   https://crautos.com/autosusados/cardetail.cfm?...    NaN
# ...                                                  ...    ...
# 11008  https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 11010  https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 11025  https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 11028  https://crautos.com/autosusados/cardetail.cfm?...    NaN
# 11052  https://crautos.com/autosusados/cardetail.cfm?...    NaN
#
#                                             Equipamiento  Cilindrada  \
# 19                                    Aire acondicionado        1500
# 39     Dirección Hidráulica/Electroasistida     Aros ...        1500
# 1119   Dirección Hidráulica/Electroasistida     Cierr...        3800
# 1303   Dirección Hidráulica/Electroasistida     Cierr...        3000
# 2267   Dirección Hidráulica/Electroasistida     Cierr...        3600
# ...                                                  ...         ...
# 11008  Dirección Hidráulica/Electroasistida     Cierr...        6200
# 11010  Dirección Hidráulica/Electroasistida     Cierr...        5700
# 11025                                                NaN        3000
# 11028  Dirección Hidráulica/Electroasistida     Cierr...        3000
# 11052  Dirección Hidráulica/Electroasistida     Cierr...        6200
#
#                  Estilo # de pasajeros Combustible      Transmisión  \
# 19                Sedán              5    Gasolina           Manual
# 39                Sedán              5    Gasolina           Manual
# 1119   Microbús/Minivan              7     Híbrido           Manual
# 1303        SUV 4WD/AWD              7      Diesel  Automática/Dual
# 2267            SUV 2WD              7    Gasolina  Automática/Dual
# ...                 ...            ...         ...              ...
# 11008             Sedán              5    Gasolina  Automática/Dual
# 11010       Pick Up 4WD              5    Gasolina  Automática/Dual
# 11025       Pick Up 4WD              5    Gasolina  Automática/Dual
# 11028       Pick Up 4WD              5    Gasolina  Automática/Dual
# 11052       Pick Up 4WD              5    Gasolina  Automática/Dual
#
#           Estado  Kilometraje  ...  aire acondicionado climatizado  \
# 19     Excelente       235000  ...                               0
# 39         Bueno       150000  ...                               0
# 1119   Excelente       260713  ...                               1
# 1303   Muy Bueno       221605  ...                               0
# 2267   Muy Bueno       234964  ...                               0
# ...          ...          ...  ...                             ...
# 11008  Excelente        14484  ...                               1
# 11010  Excelente         9000  ...                               0
# 11025  Excelente        11000  ...                               0
# 11028  Excelente         1800  ...                               1
# 11052  Excelente         <NA>  ...                               1
#
#       asiento con memoria retrovisores auto-retractibles  \
# 19                      0                              0
# 39                      0                              0
# 1119                    0                              0
# 1303                    0                              0
# 2267                    0                              0
# ...                   ...                            ...
# 11008                   0                              1
# 11010                   0                              1
# 11025                   0                              0
# 11028                   0                              0
# 11052                   0                              1
#
#        luces de xenón/bixenón sensor de lluvia  \
# 19                          0                0
# 39                          0                0
# 1119                        0                0
# 1303                        1                0
# 2267                        1                0
# ...                       ...              ...
# 11008                       1                1
# 11010                       1                1
# 11025                       0                0
# 11028                       1                1
# 11052                       1                1
#
#       llave inteligente/botón de arranque apple carplay computadora de viaje  \
# 19                                      0             0                    0
# 39                                      0             0                    0
# 1119                                    0             0                    0
# 1303                                    0             0                    0
# 2267                                    1             0                    0
# ...                                   ...           ...                  ...
# 11008                                   1             0                    1
# 11010                                   1             1                    1
# 11025                                   0             0                    0
# 11028                                   1             1                    1
# 11052                                   1             0                    1
#
#       volante ajustable  bluetooth
# 19                    0          0
# 39                    0          0
# 1119                  1          0
# 1303                  1          1
# 2267                  1          0
# ...                 ...        ...
# 11008                 1          0
# 11010                 1          1
# 11025                 0          0
# 11028                 1          1
# 11052                 1          1
#
# [92 rows x 64 columns]

# %% [markdown]
# Removing the rows with null values in the column 'Marca' since it's only 92 rows

# %%
df = df[df['Marca'].notna()]

# %% [markdown]
# Filling the null values on the column 'Kilometraje with the median 'Kilometraje' by 'Edad'

# %%
df[df['Kilometraje'].isna()][['Marca', 'Modelo', 'Edad', 'PrecioCRC']].sample(100)
# Out:
#            Marca             Modelo  Edad  PrecioCRC
# 10361     toyota  land cruiser fj62    37   25100000
# 230        isuzu                 kb    35    2200000
# 2167      toyota               rav4    22    4800000
# 5561       chery            tiggo 2     5    8341590
# 1822     hyundai           terracan    18    4500000
# ...          ...                ...   ...        ...
# 3331      toyota          corolla s    15    5800000
# 1380       honda                crv    25    4200000
# 7728   chevrolet          camaro rs    35   11500000
# 1112   chevrolet              spark    14    3900000
# 12           jac                 j2    13     800000
#
# [100 rows x 4 columns]

# %%
# Step 1: Temporarily cast to float (bypasses Int64 safety check)
df['Kilometraje'] = df['Kilometraje'].astype(float)

# Step 2: Fill missing values using median grouped by Edad
df['Kilometraje'] = df['Kilometraje'].fillna(
    df.groupby('Edad')['Kilometraje'].transform('median')
)

# Step 3: Round and convert back to Int64
df['Kilometraje'] = df['Kilometraje'].round().astype('Int64')

# %% [markdown]
# Remove unnecessary columns

# %%
df.drop(columns=['CRA_URL', 'Placa','Fecha de ingreso', 'Año','Equipamiento','Equipamiento_clean','Color exterior','Color interior'], inplace=True)

# %%
# Making a list of all categorical variables
cat_col = list(df.select_dtypes("object").columns)

# Printing the count of each unique value
for column in cat_col:
    print(df[column].value_counts())
    print("-" * 50)
# Out:
# Modelo
# tucson                  404
# rav4                    279
# yaris                   247
# qashqai                 180
# sportage                179
#                        ...
# benz g63 amg w463         1
# x6m competition           1
# f150 raptor r             1
# benz gle53 coupe amg      1
# 911                       1
# Name: count, Length: 1901, dtype: int64
# --------------------------------------------------
# Estilo
# SUV 4WD/AWD               3285
# SUV 2WD                   2538
# Sedán                     2365
# Pick Up 4WD                924
# Hatchback                  877
# Microbús/Minivan           177
# Pick Up 2WD                174
# Camión 1.0-3.5 ton.         90
# Station Wagon               79
# Pánel                       62
# Camión 4.0-4.5 ton.         14
# Camión 5.0-7.5 ton.         14
# Camión 8.0-9.5 ton.          5
# Camión 10.0 ton. o más       5
# Casa Rodante                 2
# Name: count, dtype: int64
# --------------------------------------------------
# # de pasajeros
# 5     8201
# 7     1321
# 4      440
# 3      181
# 10     135
# 8      123
# 2      121
# 6       73
# 9       13
# ND       2
# 1        1
# Name: count, dtype: int64
# --------------------------------------------------
# Combustible
# Gasolina    7822
# Diesel      2547
# Híbrido      242
# Name: count, dtype: int64
# --------------------------------------------------
# Transmisión
# Automática/Dual    7165
# Manual             3446
# Name: count, dtype: int64
# --------------------------------------------------
# Estado
# Excelente    8388
# Muy Bueno    1717
# Bueno         394
# Regular       112
# Name: count, dtype: int64
# --------------------------------------------------
# Ya pagó impuestos
# SI    10575
# NO       36
# Name: count, dtype: int64
# --------------------------------------------------
# Precio negociable
# SI    8318
# NO    2293
# Name: count, dtype: int64
# --------------------------------------------------
# Se recibe vehículo
# NO    7508
# SI    3103
# Name: count, dtype: int64
# --------------------------------------------------
# Provincia
# San José      5084
# Heredia       1849
# Alajuela      1720
# Cartago       1237
# Guanacaste     323
# Puntarenas     239
# Limón          159
# Name: count, dtype: int64
# --------------------------------------------------
# Marca
# toyota      1847
# hyundai     1455
# nissan      1100
# suzuki       716
# kia          625
#             ...
# buick          1
# jaecoo         1
# hummer         1
# bluebird       1
# bentley        1
# Name: count, Length: 78, dtype: int64
# --------------------------------------------------

# %% [markdown]
# ## Handling Outliers

# %%
df.describe(include = "all").T
# Out:
#                                         count unique              top   freq  \
# Modelo                                  10611   1901           tucson    404
# Cilindrada                            10611.0   <NA>             <NA>   <NA>
# Estilo                                  10611     15      SUV 4WD/AWD   3285
# # de pasajeros                          10611     11                5   8201
# Combustible                             10611      3         Gasolina   7822
# Transmisión                             10611      2  Automática/Dual   7165
# Estado                                  10611      4        Excelente   8388
# Kilometraje                           10610.0   <NA>             <NA>   <NA>
# # de puertas                          10611.0    NaN              NaN    NaN
# Ya pagó impuestos                       10611      2               SI  10575
# Precio negociable                       10611      2               SI   8318
# Se recibe vehículo                      10611      2               NO   7508
# Provincia                               10611      7         San José   5084
# PrecioCRC                             10611.0    NaN              NaN    NaN
# PrecioUSD                             10611.0    NaN              NaN    NaN
# Marca                                   10611     78           toyota   1847
# Edad                                  10611.0   <NA>             <NA>   <NA>
# dirección hidráulica/electroasistida  10611.0    NaN              NaN    NaN
# cierre central                        10611.0    NaN              NaN    NaN
# asientos eléctricos                   10611.0    NaN              NaN    NaN
# vidrios tintados                      10611.0    NaN              NaN    NaN
# vidrios eléctricos                    10611.0    NaN              NaN    NaN
# bolsa de aire                         10611.0    NaN              NaN    NaN
# alarma                                10611.0    NaN              NaN    NaN
# espejos eléctricos                    10611.0    NaN              NaN    NaN
# frenos abs                            10611.0    NaN              NaN    NaN
# aire acondicionado                    10611.0    NaN              NaN    NaN
# desempañador trasero                  10611.0    NaN              NaN    NaN
# sunroof/techo panorámico              10611.0    NaN              NaN    NaN
# aros de lujo                          10611.0    NaN              NaN    NaN
# turbo                                 10611.0    NaN              NaN    NaN
# tapicería de cuero                    10611.0    NaN              NaN    NaN
# halógenos                             10611.0    NaN              NaN    NaN
# cámara 360                            10611.0    NaN              NaN    NaN
# android auto                          10611.0    NaN              NaN    NaN
# control crucero                       10611.0    NaN              NaN    NaN
# radio con usb/aux                     10611.0    NaN              NaN    NaN
# revisión técnica al día               10611.0    NaN              NaN    NaN
# control electrónico de estabilidad    10611.0    NaN              NaN    NaN
# control de descenso                   10611.0    NaN              NaN    NaN
# caja de cambios dual                  10611.0    NaN              NaN    NaN
# cámara de retroceso                   10611.0    NaN              NaN    NaN
# sensores de retroceso                 10611.0    NaN              NaN    NaN
# sensores frontales                    10611.0    NaN              NaN    NaN
# control de radio en el volante        10611.0    NaN              NaN    NaN
# volante multifuncional                10611.0    NaN              NaN    NaN
# aire acondicionado climatizado        10611.0    NaN              NaN    NaN
# asiento con memoria                   10611.0    NaN              NaN    NaN
# retrovisores auto-retractibles        10611.0    NaN              NaN    NaN
# luces de xenón/bixenón                10611.0    NaN              NaN    NaN
# sensor de lluvia                      10611.0    NaN              NaN    NaN
# llave inteligente/botón de arranque   10611.0    NaN              NaN    NaN
# apple carplay                         10611.0    NaN              NaN    NaN
# computadora de viaje                  10611.0    NaN              NaN    NaN
# volante ajustable                     10611.0    NaN              NaN    NaN
# bluetooth                             10611.0    NaN              NaN    NaN
#
#                                                  mean             std  \
# Modelo                                            NaN             NaN
# Cilindrada                                2212.957968     1218.134669
# Estilo                                            NaN             NaN
# # de pasajeros                                    NaN             NaN
# Combustible                                       NaN             NaN
# Transmisión                                       NaN             NaN
# Estado                                            NaN             NaN
# Kilometraje                             128184.164467    87565.859726
# # de puertas                                 4.343417        0.751285
# Ya pagó impuestos                                 NaN             NaN
# Precio negociable                                 NaN             NaN
# Se recibe vehículo                                NaN             NaN
# Provincia                                         NaN             NaN
# PrecioCRC                             10689715.277636  8765122.538388
# PrecioUSD                                21206.016006    17353.663276
# Marca                                             NaN             NaN
# Edad                                        11.104231        7.641722
# dirección hidráulica/electroasistida         0.876637        0.328868
# cierre central                               0.865705        0.340985
# asientos eléctricos                          0.280841        0.449431
# vidrios tintados                             0.732824        0.442506
# vidrios eléctricos                           0.855716        0.351394
# bolsa de aire                                0.852135        0.354983
# alarma                                       0.572048        0.494805
# espejos eléctricos                           0.748469        0.433914
# frenos abs                                   0.730751         0.44359
# aire acondicionado                            0.89313        0.308963
# desempañador trasero                         0.699463        0.458513
# sunroof/techo panorámico                     0.185279        0.388542
# aros de lujo                                 0.725002        0.446534
# turbo                                        0.301951        0.459126
# tapicería de cuero                           0.349354        0.476789
# halógenos                                    0.621336        0.485077
# cámara 360                                   0.089435        0.285385
# android auto                                 0.244369        0.429733
# control crucero                              0.413062        0.492407
# radio con usb/aux                            0.725945        0.446058
# revisión técnica al día                      0.881632        0.323058
# control electrónico de estabilidad           0.367543        0.482159
# control de descenso                          0.255867        0.436368
# caja de cambios dual                         0.426727        0.494625
# cámara de retroceso                          0.531335        0.499041
# sensores de retroceso                        0.407784        0.491446
# sensores frontales                           0.186316         0.38938
# control de radio en el volante               0.581849        0.493278
# volante multifuncional                       0.472434        0.499263
# aire acondicionado climatizado               0.396852        0.489268
# asiento con memoria                               0.0             0.0
# retrovisores auto-retractibles               0.277731        0.447901
# luces de xenón/bixenón                       0.243615        0.429283
# sensor de lluvia                             0.231175        0.421604
# llave inteligente/botón de arranque          0.320422        0.466661
# apple carplay                                0.217981        0.412894
# computadora de viaje                         0.302422        0.459329
# volante ajustable                            0.689473        0.462731
# bluetooth                                    0.667326        0.471193
#
#                                            min        25%        50%  \
# Modelo                                     NaN        NaN        NaN
# Cilindrada                                 0.0     1600.0     2000.0
# Estilo                                     NaN        NaN        NaN
# # de pasajeros                             NaN        NaN        NaN
# Combustible                                NaN        NaN        NaN
# Transmisión                                NaN        NaN        NaN
# Estado                                     NaN        NaN        NaN
# Kilometraje                                1.0    67000.0   114000.0
# # de puertas                               1.0        4.0        4.0
# Ya pagó impuestos                          NaN        NaN        NaN
# Precio negociable                          NaN        NaN        NaN
# Se recibe vehículo                         NaN        NaN        NaN
# Provincia                                  NaN        NaN        NaN
# PrecioCRC                             300000.0  5275000.0  8400000.0
# PrecioUSD                                594.0    10446.0    16700.0
# Marca                                      NaN        NaN        NaN
# Edad                                       0.0        6.0        9.0
# dirección hidráulica/electroasistida       0.0        1.0        1.0
# cierre central                             0.0        1.0        1.0
# asientos eléctricos                        0.0        0.0        0.0
# vidrios tintados                           0.0        0.0        1.0
# vidrios eléctricos                         0.0        1.0        1.0
# bolsa de aire                              0.0        1.0        1.0
# alarma                                     0.0        0.0        1.0
# espejos eléctricos                         0.0        0.0        1.0
# frenos abs                                 0.0        0.0        1.0
# aire acondicionado                         0.0        1.0        1.0
# desempañador trasero                       0.0        0.0        1.0
# sunroof/techo panorámico                   0.0        0.0        0.0
# aros de lujo                               0.0        0.0        1.0
# turbo                                      0.0        0.0        0.0
# tapicería de cuero                         0.0        0.0        0.0
# halógenos                                  0.0        0.0        1.0
# cámara 360                                 0.0        0.0        0.0
# android auto                               0.0        0.0        0.0
# control crucero                            0.0        0.0        0.0
# radio con usb/aux                          0.0        0.0        1.0
# revisión técnica al día                    0.0        1.0        1.0
# control electrónico de estabilidad         0.0        0.0        0.0
# control de descenso                        0.0        0.0        0.0
# caja de cambios dual                       0.0        0.0        0.0
# cámara de retroceso                        0.0        0.0        1.0
# sensores de retroceso                      0.0        0.0        0.0
# sensores frontales                         0.0        0.0        0.0
# control de radio en el volante             0.0        0.0        1.0
# volante multifuncional                     0.0        0.0        0.0
# aire acondicionado climatizado             0.0        0.0        0.0
# asiento con memoria                        0.0        0.0        0.0
# retrovisores auto-retractibles             0.0        0.0        0.0
# luces de xenón/bixenón                     0.0        0.0        0.0
# sensor de lluvia                           0.0        0.0        0.0
# llave inteligente/botón de arranque        0.0        0.0        0.0
# apple carplay                              0.0        0.0        0.0
# computadora de viaje                       0.0        0.0        0.0
# volante ajustable                          0.0        0.0        1.0
# bluetooth                                  0.0        0.0        1.0
#
#                                              75%          max
# Modelo                                       NaN          NaN
# Cilindrada                                2500.0      45000.0
# Estilo                                       NaN          NaN
# # de pasajeros                               NaN          NaN
# Combustible                                  NaN          NaN
# Transmisión                                  NaN          NaN
# Estado                                       NaN          NaN
# Kilometraje                            172312.25    1416219.0
# # de puertas                                 5.0          5.0
# Ya pagó impuestos                            NaN          NaN
# Precio negociable                            NaN          NaN
# Se recibe vehículo                           NaN          NaN
# Provincia                                    NaN          NaN
# PrecioCRC                             12750000.0  123725000.0
# PrecioUSD                                25348.0     244029.7
# Marca                                        NaN          NaN
# Edad                                        14.0         65.0
# dirección hidráulica/electroasistida         1.0          1.0
# cierre central                               1.0          1.0
# asientos eléctricos                          1.0          1.0
# vidrios tintados                             1.0          1.0
# vidrios eléctricos                           1.0          1.0
# bolsa de aire                                1.0          1.0
# alarma                                       1.0          1.0
# espejos eléctricos                           1.0          1.0
# frenos abs                                   1.0          1.0
# aire acondicionado                           1.0          1.0
# desempañador trasero                         1.0          1.0
# sunroof/techo panorámico                     0.0          1.0
# aros de lujo                                 1.0          1.0
# turbo                                        1.0          1.0
# tapicería de cuero                           1.0          1.0
# halógenos                                    1.0          1.0
# cámara 360                                   0.0          1.0
# android auto                                 0.0          1.0
# control crucero                              1.0          1.0
# radio con usb/aux                            1.0          1.0
# revisión técnica al día                      1.0          1.0
# control electrónico de estabilidad           1.0          1.0
# control de descenso                          1.0          1.0
# caja de cambios dual                         1.0          1.0
# cámara de retroceso                          1.0          1.0
# sensores de retroceso                        1.0          1.0
# sensores frontales                           0.0          1.0
# control de radio en el volante               1.0          1.0
# volante multifuncional                       1.0          1.0
# aire acondicionado climatizado               1.0          1.0
# asiento con memoria                          0.0          0.0
# retrovisores auto-retractibles               1.0          1.0
# luces de xenón/bixenón                       0.0          1.0
# sensor de lluvia                             0.0          1.0
# llave inteligente/botón de arranque          1.0          1.0
# apple carplay                                0.0          1.0
# computadora de viaje                         1.0          1.0
# volante ajustable                            1.0          1.0
# bluetooth                                    1.0          1.0

# %%
df.drop(columns=['asiento con memoria'], inplace=True)

# %% [markdown]
# Both the columns Cilindrada and Kilometraje have very unrealistic values, we will cap them.

# %%
# Cap (clip) engine size to a maximum realistic value of 8000 cc
# Any value above 8000 will be replaced with 8000
# This helps remove extreme outliers likely due to data entry errors
df['Cilindrada'] = df['Cilindrada'].clip(upper=8000)

# %%
# Cap mileage to a maximum of 600,000 km
# Vehicles with higher mileage are rare and may be incorrect or exceptional cases
# This prevents those extreme values from skewing statistical analyses or ML models
df['Kilometraje'] = df['Kilometraje'].clip(upper=600000)

# %% [markdown]
# #EDA

# %% [markdown]
# ##Univariate Analysis

# %%
# Function to plot a boxplot and a histogram along the same scale

def histogram_boxplot(data, feature, figsize = (12, 7), kde = False, bins = None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows = 2,      # Number of rows of the subplot grid = 2
        sharex = True,  # x-axis will be shared among all subplots
        gridspec_kw = {"height_ratios": (0.25, 0.75)},
        figsize = figsize,
    )                   # Creating the 2 subplots
    sns.boxplot(
        data = data, x = feature, ax = ax_box2, showmeans = True, color = "violet"
    )                   # Boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data = data, x = feature, kde = kde, ax = ax_hist2, bins = bins, palette = "winter"
    ) if bins else sns.histplot(
        data = data, x = feature, kde = kde, ax = ax_hist2
    )                   # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color = "green", linestyle = "--"
    )                   # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color = "black", linestyle = "-"
    )                   # Add median to the histogram

# %%
histogram_boxplot(df, "Cilindrada")
# Function to check the skewness of a variable
skewness_value = df['Cilindrada'].skew()

print("Skewness of 'Cilindrada':", skewness_value)
# Out:
# Skewness of 'Cilindrada': 2.000406845554984

# %%
histogram_boxplot(df, "Kilometraje")
# Function to check the skewness of a variable
skewness_value = df['Kilometraje'].skew()

print("Skewness of 'Kilometraje':", skewness_value)
# Out:
# Skewness of 'Kilometraje': 1.2879968289800794

# %%
histogram_boxplot(df, "PrecioCRC")
# Function to check the skewness of a variable
skewness_value = df['PrecioCRC'].skew()

print("Skewness of 'PrecioCRC':", skewness_value)
# Out:
# Skewness of 'PrecioCRC': 3.2301266951121463

# %%
histogram_boxplot(df, "PrecioUSD")
# Function to check the skewness of a variable
skewness_value = df['PrecioUSD'].skew()

print("Skewness of 'PrecioUSD':", skewness_value)
# Out:
# Skewness of 'PrecioUSD': 3.2108041212440828

# %%
histogram_boxplot(df, "Edad")
# Function to check the skewness of a variable
skewness_value = df['Edad'].skew()

print("Skewness of 'Edad':", skewness_value)
# Out:
# Skewness of 'Edad': 1.618920277537182

# %%
# Function to create labeled barplots

def labeled_barplot(data, feature, perc = False, n = None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])            # Length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize = (count + 1, 5))
    else:
        plt.figure(figsize = (n + 1, 5))

    plt.xticks(rotation = 90, fontsize = 15)
    ax = sns.countplot(
        data = data,
        x = feature,
        palette = "Paired",
        order = data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )                              # Percentage of each class of the category
        else:
            label = p.get_height()         # Count of each level of the category

        x = p.get_x() + p.get_width() / 2  # Width of the plot
        y = p.get_height()                 # Height of the plot

        ax.annotate(
            label,
            (x, y),
            ha = "center",
            va = "center",
            size = 12,
            xytext = (0, 5),
            textcoords = "offset points",
        )                                 # Annotate the percentage

    plt.show()                            # Show the plot

# %%
labeled_barplot(df, "# de pasajeros", perc = True)

# %% [markdown]
# The column '# de pasajeros' has very little values of 1, which is most likely an error, we will remove all the rows with the value 1 on '# de pasajeros'

# %%
df = df[(df['# de pasajeros'] != 'ND') & (df['# de pasajeros'] != '1')]

# %%
labeled_barplot(df, "# de puertas", perc = True)

# %%
df = df[df['# de puertas'] != 1]

# %% [markdown]
# The column '# de puerta' has very little values of 1, which is most likely an error, we will remove all the rows with the value 1 on '# de puerta'

# %%
labeled_barplot(df, "Estilo", perc = True)

# %%
# Group all 'Camión ...' entries into a single 'Camión' category
df['Estilo'] = df['Estilo'].apply(lambda x: 'Camión' if isinstance(x, str) and x.startswith('Camión') else x)

# %%
labeled_barplot(df, "Estilo", perc = True)

# %%
labeled_barplot(df, "Combustible", perc = True)

# %%
labeled_barplot(df, "Transmisión", perc = True)

# %%
labeled_barplot(df, "Estado", perc = True)

# %% [markdown]
# ##Heatmap

# %%
cols_list = df.select_dtypes(include = np.number).columns.tolist()

plt.figure(figsize = (10, 5))
sns.heatmap(
    df[cols_list].corr(), annot = True, vmin = -1, vmax = 1, fmt = ".2f", cmap = "Spectral"
)
plt.show()

# %% [markdown]
# #Building Models

# %% [markdown]
# ##Dummy Variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10605 entries, 0 to 11055
# Data columns (total 55 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Modelo                                10605 non-null  object
#  1   Cilindrada                            10605 non-null  Int64
#  2   Estilo                                10605 non-null  object
#  3   # de pasajeros                        10605 non-null  object
#  4   Combustible                           10605 non-null  object
#  5   Transmisión                           10605 non-null  object
#  6   Estado                                10605 non-null  object
#  7   Kilometraje                           10605 non-null  Int64
#  8   # de puertas                          10605 non-null  int64
#  9   Ya pagó impuestos                     10605 non-null  object
#  10  Precio negociable                     10605 non-null  object
#  11  Se recibe vehículo                    10605 non-null  object
#  12  Provincia                             10605 non-null  object
#  13  PrecioCRC                             10605 non-null  int64
#  14  PrecioUSD                             10605 non-null  float64
#  15  Marca                                 10605 non-null  object
#  16  Edad                                  10605 non-null  Int64
#  17  dirección hidráulica/electroasistida  10605 non-null  int64
#  18  cierre central                        10605 non-null  int64
#  19  asientos eléctricos                   10605 non-null  int64
#  20  vidrios tintados                      10605 non-null  int64
#  21  vidrios eléctricos                    10605 non-null  int64
#  22  bolsa de aire                         10605 non-null  int64
#  23  alarma                                10605 non-null  int64
#  24  espejos eléctricos                    10605 non-null  int64
#  25  frenos abs                            10605 non-null  int64
#  26  aire acondicionado                    10605 non-null  int64
#  27  desempañador trasero                  10605 non-null  int64
#  28  sunroof/techo panorámico              10605 non-null  int64
#  29  aros de lujo                          10605 non-null  int64
#  30  turbo                                 10605 non-null  int64
#  31  tapicería de cuero                    10605 non-null  int64
#  32  halógenos                             10605 non-null  int64
#  33  cámara 360                            10605 non-null  int64
#  34  android auto                          10605 non-null  int64
#  35  control crucero                       10605 non-null  int64
#  36  radio con usb/aux                     10605 non-null  int64
#  37  revisión técnica al día               10605 non-null  int64
#  38  control electrónico de estabilidad    10605 non-null  int64
#  39  control de descenso                   10605 non-null  int64
#  40  caja de cambios dual                  10605 non-null  int64
#  41  cámara de retroceso                   10605 non-null  int64
#  42  sensores de retroceso                 10605 non-null  int64
#  43  sensores frontales                    10605 non-null  int64
#  44  control de radio en el volante        10605 non-null  int64
#  45  volante multifuncional                10605 non-null  int64
#  46  aire acondicionado climatizado        10605 non-null  int64
#  47  retrovisores auto-retractibles        10605 non-null  int64
#  48  luces de xenón/bixenón                10605 non-null  int64
#  49  sensor de lluvia                      10605 non-null  int64
#  50  llave inteligente/botón de arranque   10605 non-null  int64
#  51  apple carplay                         10605 non-null  int64
#  52  computadora de viaje                  10605 non-null  int64
#  53  volante ajustable                     10605 non-null  int64
#  54  bluetooth                             10605 non-null  int64
# dtypes: Int64(3), float64(1), int64(40), object(11)
# memory usage: 4.6+ MB

# %% [markdown]
# Converting the dummy variables previously created into object

# %%
columns_to_convert = [
    'dirección hidráulica/electroasistida', 'cierre central', 'asientos eléctricos',
    'vidrios tintados', 'vidrios eléctricos', 'bolsa de aire', 'alarma', 'espejos eléctricos',
    'frenos abs', 'aire acondicionado', 'desempañador trasero', 'sunroof/techo panorámico',
    'aros de lujo', 'turbo', 'tapicería de cuero', 'halógenos', 'cámara 360', 'android auto',
    'control crucero', 'radio con usb/aux', 'revisión técnica al día',
    'control electrónico de estabilidad', 'control de descenso', 'caja de cambios dual',
    'cámara de retroceso', 'sensores de retroceso', 'sensores frontales',
    'control de radio en el volante', 'volante multifuncional', 'aire acondicionado climatizado',
    'retrovisores auto-retractibles', 'luces de xenón/bixenón', 'sensor de lluvia',
    'llave inteligente/botón de arranque', 'apple carplay', 'computadora de viaje',
    'volante ajustable', 'bluetooth'
]

# Convert to object
df[columns_to_convert] = df[columns_to_convert].astype('object')

# %%
df['# de pasajeros'] = df['# de pasajeros'].astype('Int64')

# %%
df.drop(columns=['Modelo','PrecioCRC'], inplace=True)

# %%
# 1. Create target variable
y = df['PrecioUSD']
# 2. Drop columns not needed in X
X = df.drop(['PrecioUSD'], axis=1)

# 3. Encode categorical columns
def encode_cat_vars(x):
    return pd.get_dummies(
        x,
        columns=x.select_dtypes(include=["object"]).columns.tolist(),
        drop_first=True,
    )

X = encode_cat_vars(X)

# %%
print(f"Shape of X: {X.shape}")
print(f"Number of features: {X.shape[1]}")
# Out:
# Shape of X: (10605, 144)
# Number of features: 144

# %%
# List of features to drop
'''features_to_drop = [
    "Marca_faw", "Marca_baic", "Marca_omoda", "Marca_hummer", "Marca_cmc",
    "Marca_jaecoo", "Marca_datsun", "Marca_zotye", "Marca_jetour", "Marca_vgv",
    "Marca_infiniti", "Marca_international", "Marca_samsung", "Marca_freightliner",
    "Marca_chrysler", "Marca_buick", "Marca_rover", "Marca_geo", "Marca_brilliance",
    "Marca_skoda", "Marca_daewoo", "Marca_piaggio", "Marca_alfa", "Marca_lada",
    "Marca_mahindra", "Marca_zap"
]

# Drop from df
X = X.drop(columns=features_to_drop, errors="ignore")'''
# Out:
# 'features_to_drop = [\n    "Marca_faw", "Marca_baic", "Marca_omoda", "Marca_hummer", "Marca_cmc",\n    "Marca_jaecoo", "Marca_datsun", "Marca_zotye", "Marca_jetour", "Marca_vgv",\n    "Marca_infiniti", "Marca_international", "Marca_samsung", "Marca_freightliner",\n    "Marca_chrysler", "Marca_buick", "Marca_rover", "Marca_geo", "Marca_brilliance",\n    "Marca_skoda", "Marca_daewoo", "Marca_piaggio", "Marca_alfa", "Marca_lada",\n    "Marca_mahindra", "Marca_zap"\n]\n\n# Drop from df\nX = X.drop(columns=features_to_drop, errors="ignore")'

# %%
# Splitting the data into train and test sets in 70:30 ratio
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.30, random_state = 1)

print(X_train.shape, X_test.shape)

X_train.head()
# Out:
# (7423, 144) (3182, 144)
#       Cilindrada  # de pasajeros  Kilometraje  # de puertas  Edad  \
# 1863        2000               5        72000             5    17
# 7681        2200               7        80000             5    11
# 2755        1200               5        52000             4     7
# 4412        1400               7        65500             5     7
# 8770          24               5        71371             5     5
#
#       Estilo_Casa Rodante  Estilo_Hatchback  Estilo_Microbús/Minivan  \
# 1863                False             False                    False
# 7681                False             False                    False
# 2755                False              True                    False
# 4412                False             False                    False
# 8770                False             False                    False
#
#       Estilo_Pick Up 2WD  Estilo_Pick Up 4WD  ...  volante multifuncional_1  \
# 1863               False               False  ...                     False
# 7681               False               False  ...                      True
# 2755               False               False  ...                     False
# 4412               False               False  ...                     False
# 8770               False               False  ...                      True
#
#       aire acondicionado climatizado_1  retrovisores auto-retractibles_1  \
# 1863                             False                              True
# 7681                             False                             False
# 2755                             False                             False
# 4412                             False                             False
# 8770                             False                             False
#
#       luces de xenón/bixenón_1  sensor de lluvia_1  \
# 1863                     False               False
# 7681                     False               False
# 2755                     False               False
# 4412                     False               False
# 8770                     False               False
#
#       llave inteligente/botón de arranque_1  apple carplay_1  \
# 1863                                  False            False
# 7681                                  False            False
# 2755                                  False            False
# 4412                                   True            False
# 8770                                   True            False
#
#       computadora de viaje_1  volante ajustable_1  bluetooth_1
# 1863                   False                 True        False
# 7681                   False                 True        False
# 2755                   False                 True         True
# 4412                   False                 True         True
# 8770                   False                 True         True
#
# [5 rows x 144 columns]

# %% [markdown]
# #XGBoost Regressor

# %%
# Installing the xgboost library using the 'pip' command
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (3.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.16.1)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Function to compute adjusted R-squared
def adj_r2_score(predictors, targets, predictions):
    r2 = r2_score(targets, predictions)
    n = predictors.shape[0]
    k = predictors.shape[1]
    return 1 - ((1 - r2) * (n - 1) / (n - k - 1))


# Function to compute MAPE
def mape_score(targets, predictions):
    return np.mean(np.abs(targets - predictions) / targets) * 100

# Function to compute different metrics to check performance of a regression model
def model_performance_regression(model, predictors, target):
    """
    Function to compute different metrics to check regression model performance

    model: regressor
    predictors: independent variables
    target: dependent variable
    """

    pred = model.predict(predictors)                  # Predict using the independent variables
    r2 = r2_score(target, pred)                       # To compute R-squared
    adjr2 = adj_r2_score(predictors, target, pred)    # To compute adjusted R-squared
    rmse = np.sqrt(mean_squared_error(target, pred))  # To compute RMSE
    mae = mean_absolute_error(target, pred)           # To compute MAE
    mape = mape_score(target, pred)                   # To compute MAPE

    # Creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "RMSE": rmse,
            "MAE": mae,
            "R-squared": r2,
            "Adj. R-squared": adjr2,
            "MAPE": mape,
        },
        index=[0],
    )

    return df_perf

# %%
# Importing XGBoost Regressor
from xgboost import XGBRegressor

# XGBoost Regressor
xgb = XGBRegressor(random_state = 1)

# Fitting the model
xgb.fit(X_train,y_train)

# Model Performance on the test data
xgb_perf_test = model_performance_regression(xgb, X_test, y_test)

xgb_perf_test
# Out:
#           RMSE          MAE  R-squared  Adj. R-squared      MAPE
# 0  7210.799016  3239.237716   0.833131        0.825219  15.63335

# %% [markdown]
# ##Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Define which columns are numeric and which are categorical
numeric_features = ['Edad', 'Kilometraje', 'Cilindrada']
categorical_features = [col for col in X_train.columns if col not in numeric_features]

# Preprocessor: scale numeric features and one-hot encode categorical features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
    ]
)

# Fit-transform the training data, transform the test data
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# Scale the target variable (Precio)
target_scaler = StandardScaler()
y_train_scaled = target_scaler.fit_transform(y_train.values.reshape(-1, 1)).ravel()
y_test_scaled = target_scaler.transform(y_test.values.reshape(-1, 1)).ravel()

# Neural Network model definition
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_transformed.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1)  # Single output for regression
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train_transformed, y_train_scaled,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# Predict and inverse transform the target
y_pred_scaled = model.predict(X_test_transformed).flatten()
y_pred = target_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

# Evaluate the model
rmse_nn = np.sqrt(mean_squared_error(y_test, y_pred))
r2_nn = r2_score(y_test, y_pred)

print(f"Neural Network RMSE: {rmse_nn:.2f}")
print(f"Neural Network R² Score: {r2_nn:.4f}")
# Out:
# Epoch 1/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.8680 - root_mean_squared_error: 0.9272 - val_loss: 0.4972 - val_root_mean_squared_error: 0.7051
# Epoch 2/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4874 - root_mean_squared_error: 0.6977 - val_loss: 0.3077 - val_root_mean_squared_error: 0.5547
# Epoch 3/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3531 - root_mean_squared_error: 0.5931 - val_loss: 0.2554 - val_root_mean_squared_error: 0.5054
# Epoch 4/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3148 - root_mean_squared_error: 0.5604 - val_loss: 0.3512 - val_root_mean_squared_error: 0.5926
# Epoch 5/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3315 - root_mean_squared_error: 0.5746 - val_loss: 0.2567 - val_root_mean_squared_error: 0.5067
# Epoch 6/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3051 - root_mean_squared_error: 0.5520 - val_loss: 0.2254 - val_root_mean_squared_error: 0.4748
# Epoch 7/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2762 - root_mean_squared_error: 0.5251 - val_loss: 0.2330 - val_root_mean_squared_error: 0.4827
# Epoch 8/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2725 - root_mean_squared_error: 0.5217 - val_loss: 0.3229 - val_root_mean_squared_error: 0.5683
# Epoch 9/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2495 - root_mean_squared_error: 0.4987 - val_loss: 0.1861 - val_root_mean_squared_error: 0.4314
# Epoch 10/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2569 - root_mean_squared_error: 0.5065 - val_loss: 0.2060 - val_root_mean_squared_error: 0.4539
# Epoch 11/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3265 - root_mean_squared_error: 0.5673 - val_loss: 0.1774 - val_root_mean_squared_error: 0.4212
# Epoch 12/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2306 - root_mean_squared_error: 0.4798 - val_loss: 0.1681 - val_root_mean_squared_error: 0.4100
# Epoch 13/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2495 - root_mean_squared_error: 0.4991 - val_loss: 0.1556 - val_root_mean_squared_error: 0.3944
# Epoch 14/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2006 - root_mean_squared_error: 0.4473 - val_loss: 0.1689 - val_root_mean_squared_error: 0.4110
# Epoch 15/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2590 - root_mean_squared_error: 0.5086 - val_loss: 0.1742 - val_root_mean_squared_error: 0.4174
# Epoch 16/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2232 - root_mean_squared_error: 0.4720 - val_loss: 0.1543 - val_root_mean_squared_error: 0.3928
# Epoch 17/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2061 - root_mean_squared_error: 0.4536 - val_loss: 0.1630 - val_root_mean_squared_error: 0.4037
# Epoch 18/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2407 - root_mean_squared_error: 0.4883 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3916
# Epoch 19/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1964 - root_mean_squared_error: 0.4425 - val_loss: 0.1598 - val_root_mean_squared_error: 0.3998
# Epoch 20/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2352 - root_mean_squared_error: 0.4844 - val_loss: 0.1743 - val_root_mean_squared_error: 0.4174
# Epoch 21/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2164 - root_mean_squared_error: 0.4646 - val_loss: 0.1637 - val_root_mean_squared_error: 0.4046
# Epoch 22/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2055 - root_mean_squared_error: 0.4514 - val_loss: 0.1536 - val_root_mean_squared_error: 0.3920
# Epoch 23/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2147 - root_mean_squared_error: 0.4631 - val_loss: 0.2273 - val_root_mean_squared_error: 0.4768
# Epoch 24/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1998 - root_mean_squared_error: 0.4468 - val_loss: 0.1510 - val_root_mean_squared_error: 0.3885
# Epoch 25/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1782 - root_mean_squared_error: 0.4211 - val_loss: 0.2278 - val_root_mean_squared_error: 0.4773
# Epoch 26/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2266 - root_mean_squared_error: 0.4756 - val_loss: 0.1472 - val_root_mean_squared_error: 0.3836
# Epoch 27/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2355 - root_mean_squared_error: 0.4818 - val_loss: 0.1435 - val_root_mean_squared_error: 0.3789
# Epoch 28/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1963 - root_mean_squared_error: 0.4427 - val_loss: 0.1959 - val_root_mean_squared_error: 0.4426
# Epoch 29/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1961 - root_mean_squared_error: 0.4422 - val_loss: 0.1364 - val_root_mean_squared_error: 0.3693
# Epoch 30/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2130 - root_mean_squared_error: 0.4578 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3830
# Epoch 31/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1931 - root_mean_squared_error: 0.4389 - val_loss: 0.1542 - val_root_mean_squared_error: 0.3927
# Epoch 32/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2072 - root_mean_squared_error: 0.4547 - val_loss: 0.1406 - val_root_mean_squared_error: 0.3750
# Epoch 33/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1883 - root_mean_squared_error: 0.4336 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3908
# Epoch 34/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2004 - root_mean_squared_error: 0.4465 - val_loss: 0.1561 - val_root_mean_squared_error: 0.3951
# Epoch 35/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2319 - root_mean_squared_error: 0.4722 - val_loss: 0.1832 - val_root_mean_squared_error: 0.4280
# Epoch 36/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2013 - root_mean_squared_error: 0.4478 - val_loss: 0.1767 - val_root_mean_squared_error: 0.4204
# Epoch 37/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1975 - root_mean_squared_error: 0.4440 - val_loss: 0.1402 - val_root_mean_squared_error: 0.3745
# Epoch 38/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1723 - root_mean_squared_error: 0.4143 - val_loss: 0.1401 - val_root_mean_squared_error: 0.3743
# Epoch 39/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1961 - root_mean_squared_error: 0.4416 - val_loss: 0.1332 - val_root_mean_squared_error: 0.3649
# Epoch 40/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2244 - root_mean_squared_error: 0.4726 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3816
# Epoch 41/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1961 - root_mean_squared_error: 0.4421 - val_loss: 0.2107 - val_root_mean_squared_error: 0.4590
# Epoch 42/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1973 - root_mean_squared_error: 0.4428 - val_loss: 0.1394 - val_root_mean_squared_error: 0.3734
# Epoch 43/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1897 - root_mean_squared_error: 0.4350 - val_loss: 0.1422 - val_root_mean_squared_error: 0.3771
# Epoch 44/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1716 - root_mean_squared_error: 0.4139 - val_loss: 0.1356 - val_root_mean_squared_error: 0.3683
# Epoch 45/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1595 - root_mean_squared_error: 0.3985 - val_loss: 0.1401 - val_root_mean_squared_error: 0.3743
# Epoch 46/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1777 - root_mean_squared_error: 0.4206 - val_loss: 0.1435 - val_root_mean_squared_error: 0.3788
# Epoch 47/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1825 - root_mean_squared_error: 0.4265 - val_loss: 0.1337 - val_root_mean_squared_error: 0.3656
# Epoch 48/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1732 - root_mean_squared_error: 0.4152 - val_loss: 0.1347 - val_root_mean_squared_error: 0.3671
# Epoch 49/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2134 - root_mean_squared_error: 0.4602 - val_loss: 0.1394 - val_root_mean_squared_error: 0.3734
# Epoch 50/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1868 - root_mean_squared_error: 0.4312 - val_loss: 0.1570 - val_root_mean_squared_error: 0.3962
# Epoch 51/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1679 - root_mean_squared_error: 0.4091 - val_loss: 0.1682 - val_root_mean_squared_error: 0.4101
# Epoch 52/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1665 - root_mean_squared_error: 0.4074 - val_loss: 0.1640 - val_root_mean_squared_error: 0.4050
# Epoch 53/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1840 - root_mean_squared_error: 0.4283 - val_loss: 0.1409 - val_root_mean_squared_error: 0.3753
# Epoch 54/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1485 - root_mean_squared_error: 0.3841 - val_loss: 0.1720 - val_root_mean_squared_error: 0.4148
# Epoch 55/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1482 - root_mean_squared_error: 0.3845 - val_loss: 0.1429 - val_root_mean_squared_error: 0.3780
# Epoch 56/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1712 - root_mean_squared_error: 0.4124 - val_loss: 0.1397 - val_root_mean_squared_error: 0.3738
# Epoch 57/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1647 - root_mean_squared_error: 0.4052 - val_loss: 0.1381 - val_root_mean_squared_error: 0.3717
# Epoch 58/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1649 - root_mean_squared_error: 0.4055 - val_loss: 0.1470 - val_root_mean_squared_error: 0.3834
# Epoch 59/200
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1811 - root_mean_squared_error: 0.4248 - val_loss: 0.1367 - val_root_mean_squared_error: 0.3697
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Neural Network RMSE: 7435.20
# Neural Network R² Score: 0.8226

# %%
# Plot training vs validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train MSE')
plt.plot(history.history['val_loss'], label='Validation MSE')
plt.title('Neural Network Training History')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 1. Initialize and train the model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# 2. Predict on test set
y_pred = lr_model.predict(X_test)

# 3. Evaluate performance
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Manual RMSE
r2 = r2_score(y_test, y_pred)

print("📊 Linear Regression Evaluation Metrics:")
print(f"MAE (Mean Absolute Error): ${mae:,.2f}")
print(f"MSE (Mean Squared Error): ${mse:,.2f}")
print(f"RMSE (Root Mean Squared Error): ${rmse:,.2f}")
print(f"R² (R-squared): {r2:.4f}")
# Out:
# 📊 Linear Regression Evaluation Metrics:
# MAE (Mean Absolute Error): $5,913.47
# MSE (Mean Squared Error): $115,679,895.97
# RMSE (Root Mean Squared Error): $10,755.46
# R² (R-squared): 0.6287

# %% [markdown]
# ##Random Forest

# %%
# Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators = 100, random_state = 1)

# Fitting the model
rf_regressor.fit(X_train, y_train)

# Model Performance on the test data
rf_regressor_perf_test = model_performance_regression(rf_regressor, X_test, y_test)

rf_regressor_perf_test
# Out:
#           RMSE          MAE  R-squared  Adj. R-squared       MAPE
# 0  7428.978675  3271.766675    0.82288        0.814482  16.008126

# %%
# Feature importance
importances = rf_regressor.feature_importances_

# Rename columns
columns = X.columns

# Create a DataFrame with features importance
importance_df = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

# %%
top_n = 50
top_features = importance_df.sort_values(by="Importance", ascending=False).head(top_n)

plt.figure(figsize=(10, 8))
sns.barplot(x="Importance", y=top_features.index, data=top_features)
plt.title(f"Top {top_n} Most Important Features")
plt.xlabel("Importance")
plt.ylabel("Features")
plt.tight_layout()
plt.show()
